# %% [markdown]
# # 1.加载数据（TIDB）

# %%
import pandas as pd
from sqlalchemy import create_engine

# 数据库连接设置，请根据您的实际数据库类型和配置进行修改
database_type = 'mysql'  # 或 'postgresql', 'sqlite', 等
username = '4JHciBfpftZR67E.root'  # 数据库用户名
password = 'aidBsAjcm2YUaFac'  # 数据库密码
host = 'gateway01.us-west-2.prod.aws.tidbcloud.com'  # 数据库主机地址
port = '4000'  # 数据库端口
database_name = 'django'  # 数据库名称

# 创建数据库引擎
engine = create_engine(f'{database_type}://{username}:{password}@{host}:{port}/{database_name}')

# 读取数据到DataFrame中
# 假设数据库中的表名与Excel文件中的数据结构相同
table_name = 'data_nonmainland'  # 数据库中的表名
query = f'SELECT * FROM {table_name}'

# 使用pandas的read_sql_query函数读取数据
dataframe = pd.read_sql_query(query, engine)

# 显示前几行数据以确认
print(dataframe.head())
# Out:
#            日期      合计     外国人     港澳    台湾省
# 0  2015-01-01  586538  359356  32461  51225
# 1  2015-02-01  442199  255894  28672  32098
# 2  2015-03-01  758521  484457  42057  62269
# 3  2015-04-01  757013  498421  47158  59697
# 4  2015-05-01  736034  506426  43845  63952

# %% [markdown]
# 2.

# %%
from sklearn.preprocessing import MinMaxScaler

# 数据标准化
scr = MinMaxScaler()
std = scr.fit_transform(inp)
# 输入数据规范化
train_x, train_y = [], []
for i in range(TIME_STEP, std.shape[0] - PRED_STEP + 1):
    train_x.append(std[i - TIME_STEP:i])
    train_y.append(std[i])
train_x, train_y = np.array(train_x), np.array(train_y)

# %%
from matplotlib import pyplot as plt


def loss(information_loss):
    plt.figure(figsize=(12, 8))
    plt.plot(information_loss)
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.show()

# %%
import tensorflow as tf
from keras import datasets, layers, optimizers, Sequential, metrics

# 构建全局网络，包含卷积层，池化层，双向LSTM层
network = Sequential([
    layers.Bidirectional(layers.LSTM(32, return_sequences=True, activation='sigmoid'),
                         input_shape=(TIME_STEP, DATA_SCALE)),
    layers.Flatten(),
    layers.Dense(DATA_SCALE, activation='sigmoid')
])
# 查看网络结构
network.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_8 (Bidirectio  (None, 4, 64)            9216
#  nal)
#
#  flatten_6 (Flatten)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 9,987
# Trainable params: 9,987
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 编译网络
network.compile(optimizer=optimizers.Adam(learning_rate=0.1),
                loss=tf.losses.binary_crossentropy,
                metrics=['accuracy']
                )
# 训练网络
model_information = network.fit(train_x, train_y, epochs=200, batch_size=1)
# 模型损失可视化
information_loss = model_information.history['loss']  # 模型训练损失
loss(information_loss)
# Out:
# Epoch 1/200
# 94/94 [==============================] - 2s 2ms/step - loss: 0.6245 - accuracy: 0.6170
# Epoch 2/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5372 - accuracy: 0.7021
# Epoch 3/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5342 - accuracy: 0.7128
# Epoch 4/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5257 - accuracy: 0.6702
# Epoch 5/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5282 - accuracy: 0.7553
# Epoch 6/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5248 - accuracy: 0.7234
# Epoch 7/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5239 - accuracy: 0.7234
# Epoch 8/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5380 - accuracy: 0.6596
# Epoch 9/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5300 - accuracy: 0.7447
# Epoch 10/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5250 - accuracy: 0.7021
# Epoch 11/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5239 - accuracy: 0.6915
# Epoch 12/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5221 - accuracy: 0.7234
# Epoch 13/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5305 - accuracy: 0.7234
# Epoch 14/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5304 - accuracy: 0.7447
# Epoch 15/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5297 - accuracy: 0.7553
# Epoch 16/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5256 - accuracy: 0.7128
# Epoch 17/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5245 - accuracy: 0.7660
# Epoch 18/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5209 - accuracy: 0.7766
# Epoch 19/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5193 - accuracy: 0.6809
# Epoch 20/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5362 - accuracy: 0.7128
# Epoch 21/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5280 - accuracy: 0.7447
# Epoch 22/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5268 - accuracy: 0.7660
# Epoch 23/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5225 - accuracy: 0.7128
# Epoch 24/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5294 - accuracy: 0.7128
# Epoch 25/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5189 - accuracy: 0.7447
# Epoch 26/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5250 - accuracy: 0.7128
# Epoch 27/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5240 - accuracy: 0.7234
# Epoch 28/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5188 - accuracy: 0.6915
# Epoch 29/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5313 - accuracy: 0.7021
# Epoch 30/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5230 - accuracy: 0.6809
# Epoch 31/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5421 - accuracy: 0.7234
# Epoch 32/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5215 - accuracy: 0.6915
# Epoch 33/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5173 - accuracy: 0.6915
# Epoch 34/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5213 - accuracy: 0.6489
# Epoch 35/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5194 - accuracy: 0.7340
# Epoch 36/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5160 - accuracy: 0.6809
# Epoch 37/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5096 - accuracy: 0.6809
# Epoch 38/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5086 - accuracy: 0.7021
# Epoch 39/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5128 - accuracy: 0.7021
# Epoch 40/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5136 - accuracy: 0.6383
# Epoch 41/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5186 - accuracy: 0.7021
# Epoch 42/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5074 - accuracy: 0.6383
# Epoch 43/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5070 - accuracy: 0.7021
# Epoch 44/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5100 - accuracy: 0.6915
# Epoch 45/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5090 - accuracy: 0.7021
# Epoch 46/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5104 - accuracy: 0.6915
# Epoch 47/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5069 - accuracy: 0.7021
# Epoch 48/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5027 - accuracy: 0.6489
# Epoch 49/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5049 - accuracy: 0.6915
# Epoch 50/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5083 - accuracy: 0.7128
# Epoch 51/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5084 - accuracy: 0.7128
# Epoch 52/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5066 - accuracy: 0.6809
# Epoch 53/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5039 - accuracy: 0.6489
# Epoch 54/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5024 - accuracy: 0.6915
# Epoch 55/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5018 - accuracy: 0.7021
# Epoch 56/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5058 - accuracy: 0.6383
# Epoch 57/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5027 - accuracy: 0.7447
# Epoch 58/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.6383
# Epoch 59/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5050 - accuracy: 0.6489
# Epoch 60/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5019 - accuracy: 0.6596
# Epoch 61/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5038 - accuracy: 0.6489
# Epoch 62/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.7553
# Epoch 63/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5044 - accuracy: 0.7128
# Epoch 64/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5084 - accuracy: 0.7340
# Epoch 65/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5061 - accuracy: 0.6596
# Epoch 66/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5043 - accuracy: 0.7021
# Epoch 67/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5024 - accuracy: 0.6915
# Epoch 68/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5030 - accuracy: 0.7021
# Epoch 69/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5033 - accuracy: 0.6702
# Epoch 70/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5061 - accuracy: 0.7021
# Epoch 71/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5042 - accuracy: 0.6702
# Epoch 72/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5012 - accuracy: 0.6702
# Epoch 73/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5147 - accuracy: 0.6809
# Epoch 74/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.6702
# Epoch 75/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5005 - accuracy: 0.6596
# Epoch 76/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5076 - accuracy: 0.6809
# Epoch 77/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5045 - accuracy: 0.6915
# Epoch 78/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5080 - accuracy: 0.6489
# Epoch 79/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5025 - accuracy: 0.6809
# Epoch 80/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5071 - accuracy: 0.6809
# Epoch 81/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5019 - accuracy: 0.6915
# Epoch 82/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5056 - accuracy: 0.7234
# Epoch 83/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5056 - accuracy: 0.6489
# Epoch 84/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5097 - accuracy: 0.7660
# Epoch 85/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.6809
# Epoch 86/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5016 - accuracy: 0.7021
# Epoch 87/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5029 - accuracy: 0.6277
# Epoch 88/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5069 - accuracy: 0.6809
# Epoch 89/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5009 - accuracy: 0.6809
# Epoch 90/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5009 - accuracy: 0.6915
# Epoch 91/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5030 - accuracy: 0.6915
# Epoch 92/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.6596
# Epoch 93/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5071 - accuracy: 0.6383
# Epoch 94/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5177 - accuracy: 0.6809
# Epoch 95/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5042 - accuracy: 0.6915
# Epoch 96/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5010 - accuracy: 0.7234
# Epoch 97/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5048 - accuracy: 0.7234
# Epoch 98/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5029 - accuracy: 0.7340
# Epoch 99/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5027 - accuracy: 0.6915
# Epoch 100/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5039 - accuracy: 0.6596
# Epoch 101/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5029 - accuracy: 0.6702
# Epoch 102/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5007 - accuracy: 0.7234
# Epoch 103/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5005 - accuracy: 0.6809
# Epoch 104/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4994 - accuracy: 0.7128
# Epoch 105/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4981 - accuracy: 0.6170
# Epoch 106/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4988 - accuracy: 0.7021
# Epoch 107/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5077 - accuracy: 0.7234
# Epoch 108/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5053 - accuracy: 0.7553
# Epoch 109/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5027 - accuracy: 0.7234
# Epoch 110/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5039 - accuracy: 0.6383
# Epoch 111/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5014 - accuracy: 0.7128
# Epoch 112/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5065 - accuracy: 0.7234
# Epoch 113/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5045 - accuracy: 0.7128
# Epoch 114/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5063 - accuracy: 0.6809
# Epoch 115/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5057 - accuracy: 0.6596
# Epoch 116/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4992 - accuracy: 0.6702
# Epoch 117/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4992 - accuracy: 0.7340
# Epoch 118/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5002 - accuracy: 0.7021
# Epoch 119/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5017 - accuracy: 0.7340
# Epoch 120/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5016 - accuracy: 0.7234
# Epoch 121/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4979 - accuracy: 0.6809
# Epoch 122/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5021 - accuracy: 0.6915
# Epoch 123/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5059 - accuracy: 0.6064
# Epoch 124/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5019 - accuracy: 0.7340
# Epoch 125/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5030 - accuracy: 0.6702
# Epoch 126/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5027 - accuracy: 0.6915
# Epoch 127/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4970 - accuracy: 0.7553
# Epoch 128/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4986 - accuracy: 0.6915
# Epoch 129/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4999 - accuracy: 0.7128
# Epoch 130/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5011 - accuracy: 0.7447
# Epoch 131/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4991 - accuracy: 0.7234
# Epoch 132/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4995 - accuracy: 0.7340
# Epoch 133/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5053 - accuracy: 0.7340
# Epoch 134/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4980 - accuracy: 0.7340
# Epoch 135/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5022 - accuracy: 0.6809
# Epoch 136/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5005 - accuracy: 0.7340
# Epoch 137/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4972 - accuracy: 0.7447
# Epoch 138/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4990 - accuracy: 0.7340
# Epoch 139/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5003 - accuracy: 0.7021
# Epoch 140/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5025 - accuracy: 0.7660
# Epoch 141/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5000 - accuracy: 0.6702
# Epoch 142/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4996 - accuracy: 0.6809
# Epoch 143/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4982 - accuracy: 0.7128
# Epoch 144/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5059 - accuracy: 0.6596
# Epoch 145/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5008 - accuracy: 0.7660
# Epoch 146/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5030 - accuracy: 0.7128
# Epoch 147/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4988 - accuracy: 0.7128
# Epoch 148/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5040 - accuracy: 0.7553
# Epoch 149/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5014 - accuracy: 0.6809
# Epoch 150/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4970 - accuracy: 0.7447
# Epoch 151/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5011 - accuracy: 0.6915
# Epoch 152/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5047 - accuracy: 0.7447
# Epoch 153/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5017 - accuracy: 0.7553
# Epoch 154/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5011 - accuracy: 0.7766
# Epoch 155/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5018 - accuracy: 0.7128
# Epoch 156/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5179 - accuracy: 0.7234
# Epoch 157/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5095 - accuracy: 0.7660
# Epoch 158/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5027 - accuracy: 0.7234
# Epoch 159/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5002 - accuracy: 0.7021
# Epoch 160/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4994 - accuracy: 0.7128
# Epoch 161/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5088 - accuracy: 0.6489
# Epoch 162/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5034 - accuracy: 0.6809
# Epoch 163/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.7447
# Epoch 164/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5046 - accuracy: 0.7021
# Epoch 165/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5008 - accuracy: 0.7021
# Epoch 166/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5010 - accuracy: 0.6915
# Epoch 167/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5018 - accuracy: 0.7340
# Epoch 168/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5037 - accuracy: 0.6915
# Epoch 169/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5012 - accuracy: 0.7128
# Epoch 170/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5017 - accuracy: 0.7021
# Epoch 171/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5016 - accuracy: 0.7234
# Epoch 172/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4990 - accuracy: 0.7660
# Epoch 173/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5008 - accuracy: 0.6489
# Epoch 174/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5068 - accuracy: 0.7021
# Epoch 175/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.6596
# Epoch 176/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4997 - accuracy: 0.7021
# Epoch 177/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5022 - accuracy: 0.7021
# Epoch 178/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4996 - accuracy: 0.7660
# Epoch 179/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5010 - accuracy: 0.7340
# Epoch 180/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4984 - accuracy: 0.7340
# Epoch 181/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4962 - accuracy: 0.7340
# Epoch 182/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4963 - accuracy: 0.7234
# Epoch 183/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4988 - accuracy: 0.7447
# Epoch 184/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4979 - accuracy: 0.7447
# Epoch 185/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4962 - accuracy: 0.6915
# Epoch 186/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4977 - accuracy: 0.7234
# Epoch 187/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4980 - accuracy: 0.7234
# Epoch 188/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4975 - accuracy: 0.7447
# Epoch 189/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5005 - accuracy: 0.6489
# Epoch 190/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4974 - accuracy: 0.7340
# Epoch 191/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4987 - accuracy: 0.6809
# Epoch 192/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4973 - accuracy: 0.7340
# Epoch 193/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4974 - accuracy: 0.7553
# Epoch 194/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4980 - accuracy: 0.6809
# Epoch 195/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5039 - accuracy: 0.7234
# Epoch 196/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5028 - accuracy: 0.7340
# Epoch 197/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4999 - accuracy: 0.7340
# Epoch 198/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4993 - accuracy: 0.7021
# Epoch 199/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.6915
# Epoch 200/200
# 94/94 [==============================] - 0s 2ms/step - loss: 0.4993 - accuracy: 0.7128

# %%
# save and evaluate
network.save('../models/nmainland_pred.h5')
flag = network.evaluate(train_x, train_y, verbose=0)
print(f'loss:{flag[0]}\nacc:{flag[1]}')
# Out:
# loss:0.4966869056224823
# acc:0.7234042286872864

# %%
# 检查模型可用性
import keras

new_network = keras.models.load_model('../models/nmainland_pred.h5')

# %%
# 单步多次预测
out = []
step = std[-TIME_STEP:]
for _ in range(PRED_LENGTH):
    tmp = new_network.predict(step.reshape(-1, TIME_STEP, DATA_SCALE))
    step = np.append(step, tmp, axis=0)
    step = np.delete(step, 0, 0)
    out.append(scr.inverse_transform(tmp).reshape(DATA_SCALE))
out = np.array(out).astype(int)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step

# %%
# 将数据重塑为数据库所能接受的，并转为csv，放入数据库
from dateutil.relativedelta import relativedelta
import datetime

# 生成时间轴
START_TIME = datetime.datetime.strptime('2023-03-01', '%Y-%m-%d')
timeline = [(START_TIME + relativedelta(months=i)).strftime('%Y-%m-%d') for i in range(PRED_LENGTH)]
timeline = np.array(timeline).reshape(PRED_LENGTH, -1)

# 生成合计项
val = np.sum(out, axis=1).astype(int).reshape(PRED_LENGTH, -1)
tmp = np.concatenate([timeline, val, out], axis=1)
res = pd.DataFrame(tmp, columns=["日期", "合计", "外国人", "港澳", "台湾省"])

# 合并成一个dataframe
res
# Out:
#             日期      合计    外国人     港澳    台湾省
# 0   2023-03-01   23077  11974   3784   7319
# 1   2023-04-01   43360  23107   6318  13935
# 2   2023-05-01   70971  39212   9053  22706
# 3   2023-06-01   74245  47191  10468  16586
# 4   2023-07-01   85752  50487  13876  21389
# 5   2023-08-01  123483  76987  17458  29038
# 6   2023-09-01  105912  63206  17071  25635
# 7   2023-10-01  147385  98662  18517  30206
# 8   2023-11-01  106726  59470  19396  27860
# 9   2023-12-01  129067  87364  15902  25801
# 10  2024-01-01  104252  56568  21380  26304
# 11  2024-02-01  116902  80957  14160  21785

# %%
# 画图
all = np.append(inp, out, axis=0)
length, size = all.shape
plt.plot(all)
# Out:
# [<matplotlib.lines.Line2D at 0x2c6710fec10>,
#  <matplotlib.lines.Line2D at 0x2c67165a9d0>,
#  <matplotlib.lines.Line2D at 0x2c67a3b7ca0>]
